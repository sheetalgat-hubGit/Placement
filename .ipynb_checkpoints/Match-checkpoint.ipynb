# %%
import pandas as pd
import numpy as np
df =pd.read_csv("Match - Sheet1.csv")
df
# Out:
#        match_id  inning         batting_team                 bowling_team  \
# 0             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...         ...     ...                  ...                          ...
# 69756       295       2      Deccan Chargers                Pune Warriors
# 69757       295       2      Deccan Chargers                Pune Warriors
# 69758       295       2      Deccan Chargers                Pune Warriors
# 69759       295       2      Deccan Chargers                Pune Warriors
# 69760       295       2      Deccan Chargers                Pune Warriors
#
#        over  ball       batsman   non_striker        bowler  is_super_over  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69761 entries, 0 to 69760
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          69761 non-null  int64
#  1   inning            69761 non-null  int64
#  2   batting_team      69761 non-null  object
#  3   bowling_team      69761 non-null  object
#  4   over              69761 non-null  int64
#  5   ball              69761 non-null  int64
#  6   batsman           69761 non-null  object
#  7   non_striker       69761 non-null  object
#  8   bowler            69761 non-null  object
#  9   is_super_over     69761 non-null  int64
#  10  wide_runs         69761 non-null  int64
#  11  bye_runs          69761 non-null  int64
#  12  legbye_runs       69761 non-null  int64
#  13  noball_runs       69761 non-null  int64
#  14  penalty_runs      69761 non-null  int64
#  15  batsman_runs      69761 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.describe()
# Out:
#            match_id        inning          over          ball  is_super_over  \
# count  69761.000000  69761.000000  69761.000000  69761.000000   69761.000000
# mean     148.317570      1.480555     10.099354      3.624145       0.000473
# std       84.899858      0.501487      5.666241      1.813831       0.021745
# min        1.000000      1.000000      1.000000      1.000000       0.000000
# 25%       75.000000      1.000000      5.000000      2.000000       0.000000
# 50%      150.000000      1.000000     10.000000      4.000000       0.000000
# 75%      221.000000      2.000000     15.000000      5.000000       0.000000
# max      295.000000      4.000000     20.000000      9.000000       1.000000
#
#           wide_runs      bye_runs   legbye_runs   noball_runs  penalty_runs  \
# count  69761.000000  69761.000000  69761.000000  69761.000000  69761.000000
# mean       0.039893      0.005591      0.022806      0.005046      0.000072
# ...

# %%
df.isnull().sum()
# Out:
# match_id                0
# inning                  0
# batting_team            0
# bowling_team            0
# over                    0
# ball                    0
# batsman                 0
# non_striker             0
# bowler                  0
# is_super_over           0
# wide_runs               0
# bye_runs                0
# legbye_runs             0
# noball_runs             0
# penalty_runs            0
# batsman_runs            0
# extra_runs              0
# total_runs              0
# player_dismissed    66245
# dismissal_kind      66245
# fielder             67232
# dtype: int64

# %%
df['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# caught               2029
# bowled                650
# run out               379
# lbw                   223
# stumped               121
# caught and bowled     106
# retired hurt            4
# hit wicket              4
# Name: count, dtype: int64

# %%
df['extra_runs'].sum()
# Out:
# np.int64(5121)

# %%
#Total runs of a batsman in this league---> overall batsman_runs
df['batsman_runs'].sum()
# Out:
# np.int64(84514)

# %%
#Total number of wide runs.
df['wide_runs'].sum()
# Out:
# np.int64(2783)

# %%
#Total runs of Virat Kohli
#find how his name is written first
df['batsman_runs'].loc[(df['batsman']=='V Kohli')].sum()
# Out:
# np.int64(1428)

# %%
#calculate total extra_runs given by a particular bowler (TS Mills)
df['extra_runs'].loc[(df['bowler']=='TS Mills')].sum()
#wide_runs given by TS Mills
# Out:
# np.int64(13)

# %%
#catches taken by Mandeep singh
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.loc[(df['dismissal_kind']=='caught') & (df['fielder']=='Mandeep Singh')]
# Out:
#        match_id  inning            batting_team                 bowling_team  \
# 11            1       1     Sunrisers Hyderabad  Royal Challengers Bangalore
# 2728         12       2          Mumbai Indians  Royal Challengers Bangalore
# 3922         17       1  Rising Pune Supergiant  Royal Challengers Bangalore
# 4691         20       2           Gujarat Lions  Royal Challengers Bangalore
# 6355         27       1   Kolkata Knight Riders  Royal Challengers Bangalore
# 9751         42       1         Kings XI Punjab  Royal Challengers Bangalore
# 69340       293       2        Delhi Daredevils              Kings XI Punjab
#
#        over  ball         batsman  non_striker       bowler  is_super_over  \
# 11        2     5       DA Warner     S Dhawan  A Choudhary              0
# 2728      3     3  MJ McClenaghan    RG Sharma     S Badree              0
# 3922     17     5    DT Christian    BA Stokes    S Aravind              0
# ...

# %%
#catches taken by Mandeep singh
len(df.loc[(df['dismissal_kind']=='caught') & (df['fielder']=='Mandeep Singh')])
# Out:
# 7

# %%
#How many times DA Warner was dismissed by A Choudhary
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
len(df.loc[(df['player_dismissed']=='DA Warner') & (df['bowler']=='A Choudhary')])
# Out:
# 1

# %%
#find number of stumpouts done by MS Dhoni
df['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# caught               2029
# bowled                650
# run out               379
# lbw                   223
# stumped               121
# caught and bowled     106
# retired hurt            4
# hit wicket              4
# Name: count, dtype: int64

# %%
len(df.loc[(df['dismissal_kind']=='stumped') & (df['fielder']=='MS Dhoni')])
# Out:
# 17

# %%
#find the batsman stumped out by MS Dhoni
df['batsman'].loc[(df['dismissal_kind']=='stumped') & (df['fielder']=='MS Dhoni')].value_counts()
# Out:
# batsman
# AT Rayudu         2
# MD Mishra         2
# BB McCullum       1
# RV Uthappa        1
# DA Warner         1
# AB de Villiers    1
# CJ Anderson       1
# AS Raut           1
# GC Smith          1
# CH Gayle          1
# DJ Hussey         1
# WP Saha           1
# MS Bisla          1
# EJG Morgan        1
# MK Tiwary         1
# Name: count, dtype: int64

# %%
#how many times S Dhawan got out by lbw.
df.loc[(df['dismissal_kind']=='lbw') & (df['player_dismissed']=='S Dhawan')]
# Out:
#        match_id  inning    batting_team     bowling_team  over  ball  \
# 31390       135       2  Mumbai Indians  Kings XI Punjab     5     1
# 46812       199       1  Mumbai Indians  Deccan Chargers     4     3
#
#         batsman   non_striker          bowler  is_super_over  ...  bye_runs  \
# 31390  S Dhawan     JP Duminy      YA Abdulla              0  ...         0
# 46812  S Dhawan  SR Tendulkar  Jaskaran Singh              0  ...         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 31390            0            0             0             0           0
# 46812            0            0             0             0           0
#
#        total_runs  player_dismissed dismissal_kind fielder
# 31390           0          S Dhawan            lbw     NaN
# 46812           0          S Dhawan            lbw     NaN
#
# [2 rows x 21 columns]

# %%
# loc[(df['dismissal_kind']=='lbw') & (df['player_dismissed']=='S Dhawan')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 loc[(df['dismissal_kind']=='lbw') & (df['player_dismissed']=='S Dhawan')]
#
# NameError: name 'loc' is not defined

# %%
df['fielder'].loc[(df['dismissal_kind']=='caught') & (df['batsman']=='S Dhawan')].value_counts()
# Out:
# fielder
# BB McCullum        2
# WP Saha            2
# RV Uthappa         2
# MS Dhoni           2
# AD Mathews         1
# Sachin Baby        1
# RA Tripathi        1
# GJ Maxwell         1
# SS Iyer            1
# C de Grandhomme    1
# JP Faulkner        1
# KC Sangakkara      1
# CK Kapugedera      1
# R Dravid           1
# PP Chawla          1
# SD Chitnis         1
# RA Jadeja          1
# SC Ganguly         1
# SK Raina           1
# SE Marsh           1
# AS Raut            1
# DL Vettori         1
# Sunny Singh        1
# RV Gomez           1
# AM Salvi           1
# JD Ryder           1
# Name: count, dtype: int64

# %%
#total number of sixes hit by MS Dhoni ---> batsman_runs==6
len(df.loc[(df['batsman_runs']==6) & (df['batsman']=='MS Dhoni')])
# Out:
# 62

# %%
#total runs scored by MS Dhoni buy hitting sixes.
df['batsman_runs'].loc[(df['batsman_runs']==6) & (df['batsman']=='MS Dhoni')].sum()
# Out:
# np.int64(372)

# %%
#find all the records of super over
df.loc[df['is_super_over']==1]
# Out:
#        match_id  inning           batting_team           bowling_team  over  \
# 8092         34       3         Mumbai Indians          Gujarat Lions     1
# 8093         34       3         Mumbai Indians          Gujarat Lions     1
# 8094         34       3         Mumbai Indians          Gujarat Lions     1
# 8095         34       3         Mumbai Indians          Gujarat Lions     1
# 8096         34       3         Mumbai Indians          Gujarat Lions     1
# 8097         34       4          Gujarat Lions         Mumbai Indians     1
# 8098         34       4          Gujarat Lions         Mumbai Indians     1
# 8099         34       4          Gujarat Lions         Mumbai Indians     1
# 8100         34       4          Gujarat Lions         Mumbai Indians     1
# 8101         34       4          Gujarat Lions         Mumbai Indians     1
# 8102         34       4          Gujarat Lions         Mumbai Indians     1
# ...
